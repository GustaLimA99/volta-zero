# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'
r = requests.get(url)
r.status_code

data_json = r.json()
df_rj = pd.DataFrame(data_json['items'])
df_rj['uf'].value_counts()
# Out:
# uf
# RJ    268
# Name: count, dtype: int64

# %%
# 2) Seu código aqui
status = df_rj.status.value_counts()
print("Os três status das solicitações mais frequentes na base são:\n")

for i in range(3):
    print(f'{i+1}º{status.index[i]}:{status.iloc[i]}')
# Out:
# Os três status das solicitações mais frequentes na base são:
#
# 1ºDeferido:106
# 2ºArquivado:53
# 3ºRegularizado:26

# %%
# 3) Seu código aqui
df_rj['ano'] = df_rj['data_status'].str.slice(0,None)
df_rj
# Out:
#      id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0        10409        Município        Pinheiral   3303955  RJ
# 1         8684        Município   Rio de Janeiro   3304557  RJ
# 2        62211        Município          Valença   3306107  RJ
# 3         5054        Município  Duque de Caxias   3301702  RJ
# 4        10745        Município   Angra dos Reis   3300100  RJ
# ..         ...              ...              ...       ...  ..
# 263      13817        Município          Valença   3306107  RJ
# 264      11338        Município  Duque de Caxias   3301702  RJ
# 265      13229        Município    Nova Friburgo   3303401  RJ
# 266      12595        Município        Nilópolis   3303203  RJ
# 267      11411        Município          Niterói   3303302  RJ
#
#                   num_pvl                          status  \
# 0                    None                        Deferido
# 1                    None                        Deferido
# 2    PVL02.008444/2022-97               Deferido (PVL-IF)
# 3                    None                        Deferido
# 4                    None                        Deferido
# ..                    ...                             ...
# 263                  None                        Deferido
# 264                  None                    Regularizado
# 265                  None                        Deferido
# 266                  None  Arquivado por decurso de prazo
# 267                  None                        Deferido
#
#              num_processo        data_protocolo                tipo_operacao  \
# 0    17944.001192/2013-47  2014-11-12T00:00:00Z  Operação contratual interna
# 1    17944.000824/2011-93  2011-11-16T00:00:00Z  Operação contratual interna
# 2                    None                  None  Operação contratual interna
# 3    17944.000031/2008-79  2008-03-27T00:00:00Z  Operação contratual interna
# 4    17944.001273/2008-80  2009-07-24T00:00:00Z  Operação contratual interna
# ..                    ...                   ...                          ...
# 263  19405.000116/2004-56  2006-02-20T00:00:00Z  Operação contratual interna
# 264  17944.001415/2006-47  2007-02-28T00:00:00Z  Operação contratual interna
# 265  17944.001968/2006-08  2007-01-18T00:00:00Z  Operação contratual interna
# 266  17944.001721/2010-60  2011-02-24T00:00:00Z  Operação contratual interna
# 267  17944.001437/2008-79  2008-09-15T00:00:00Z  Operação contratual interna
#
#                                          finalidade  \
# 0                                    Infraestrutura
# 1                                 Saneamento básico
# 2    Aquisição de máquinas, equipamentos e veículos
# 3                          PAC - Pró-Moradia - 2008
# 4                         PAC - Saneamento - 2008 B
# ..                                              ...
# 263                                            PMAT
# 264      Regularização de Dívida - Energia Elétrica
# 265                                         Provias
# 266                                         Provias
# 267                       PAC - Saneamento - 2008 B
#
#                          tipo_credor  \
# 0    Instituição Financeira Nacional
# 1    Instituição Financeira Nacional
# 2    Instituição Financeira Nacional
# 3    Instituição Financeira Nacional
# 4    Instituição Financeira Nacional
# ..                               ...
# 263  Instituição Financeira Nacional
# 264              Empresa Não Estatal
# 265  Instituição Financeira Nacional
# 266  Instituição Financeira Nacional
# 267  Instituição Financeira Nacional
#
#                                              credor moeda        valor  \
# 0    Agência de Fomento do Estado do Rio de Janeiro  Real    2500000.0
# 1                           Caixa Econômica Federal  Real  143200000.0
# 2                               Banco do Brasil S/A  Real    7148000.0
# 3                           Caixa Econômica Federal  Real   39900000.0
# 4                           Caixa Econômica Federal  Real   20177032.0
# ..                                              ...   ...          ...
# 263                             Banco do Brasil S/A  Real    1058400.0
# 264            Light - Serviços de Eletricidade S/A  Real    5532310.3
# 265                             Banco do Brasil S/A  Real    1976972.0
# 266                         Caixa Econômica Federal  Real    2200000.0
# 267                         Caixa Econômica Federal  Real    8000000.0
#
#      pvl_assoc_divida  pvl_contradado_credor data_status         ano
# 0                   0                      0  02/12/2014  02/12/2014
# 1                   1                      0  03/01/2012  03/01/2012
# 2                   0                      1  29/06/2023  29/06/2023
# 3                   0                      0  28/03/2008  28/03/2008
# 4                   0                      0  29/07/2009  29/07/2009
# ..                ...                    ...         ...         ...
# 263                 0                      0  01/03/2006  01/03/2006
# 264                 0                      0  13/03/2007  13/03/2007
# 265                 0                      0  15/02/2007  15/02/2007
# 266                 0                      0  27/06/2011  27/06/2011
# 267                 0                      0  23/09/2008  23/09/2008
#
# [268 rows x 19 columns]

# %%
# 4) Seu código aqui
df_rj['ano'].value_counts().sort_index(ascending=True)
# Out:
# ano
# 01/03/2006    1
# 01/08/2022    1
# 01/08/2024    1
# 01/09/2016    1
# 01/10/2020    1
#              ..
# 30/11/2009    2
# 31/03/2023    1
# 31/07/2019    1
# 31/07/2023    2
# 31/10/2023    1
# Name: count, Length: 207, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def uf_tipo(uf: str, tipo_interessado: str):
    response = requests.get('https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl')
    data = response.json()
    df = pd.DataFrame(data['items'])

    filtro = (df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)
    df_filtrado = df[filtro]

    return df_filtrado

# %%
# 2) Seu código aqui
uf = 'MG'
tipo_interessado = 'Município'

df_filtrado = uf_tipo(uf, tipo_interessado)

df_arquivado = df_filtrado[df_filtrado['status'] == 'Arquivado por decurso de prazo']
df_arquivado
# Out:
#       id_pleito tipo_interessado              interessado  cod_ibge  uf  \
# 2          9684        Município                  Rodeiro   3156304  MG
# 73         8926        Município            Itaú de Minas   3133758  MG
# 109        9254        Município     Santa Rita do Itueto   3159506  MG
# 111        7695        Município      Santana de Pirapama   3158508  MG
# 184       42261        Município                   Passos   3147907  MG
# ...         ...              ...                      ...       ...  ..
# 4697      12004        Município         Chapada do Norte   3116100  MG
# 4871      12705        Município  Santa Rita de Jacutinga   3159308  MG
# 4879       7413        Município               Matozinhos   3141108  MG
# 4959      12923        Município                Belo Vale   3106408  MG
# 4965      13064        Município          Bandeira do Sul   3105301  MG
#
#                    num_pvl                          status  \
# 2                     None  Arquivado por decurso de prazo
# 73                    None  Arquivado por decurso de prazo
# 109                   None  Arquivado por decurso de prazo
# 111                   None  Arquivado por decurso de prazo
# 184   PVL02.000722/2020-04  Arquivado por decurso de prazo
# ...                    ...                             ...
# 4697                  None  Arquivado por decurso de prazo
# 4871                  None  Arquivado por decurso de prazo
# 4879                  None  Arquivado por decurso de prazo
# 4959                  None  Arquivado por decurso de prazo
# 4965                  None  Arquivado por decurso de prazo
#
#               num_processo        data_protocolo                tipo_operacao  \
# 2     17944.001033/2012-61  2012-10-09T00:00:00Z  Operação contratual interna
# 73    17944.000867/2011-79  2012-11-05T00:00:00Z  Operação contratual interna
# 109   17944.000938/2011-33  2011-10-11T00:00:00Z  Operação contratual interna
# 111   17944.000635/2012-00  2012-04-25T00:00:00Z  Operação contratual interna
# 184   17944.101541/2020-59  2020-09-23T14:58:46Z  Operação contratual interna
# ...                    ...                   ...                          ...
# 4697  17944.001578/2010-14  2011-10-21T00:00:00Z  Operação contratual interna
# 4871  17944.001762/2011-37  2012-11-05T00:00:00Z  Operação contratual interna
# 4879  17944.000569/2012-60  2012-04-19T00:00:00Z  Operação contratual interna
# 4959  17944.001851/2011-83  2012-03-15T00:00:00Z  Operação contratual interna
# 4965  17944.001900/2013-40  2013-11-21T00:00:00Z  Operação contratual interna
#
#                                           finalidade  \
# 2                                       Provias 2012
# 73                                    Infraestrutura
# 109                                          Provias
# 111                                   Infraestrutura
# 184                                   Infraestrutura
# ...                                              ...
# 4697                          Caminho da Escola 2010
# 4871  Aquisição de máquinas, equipamentos e veículos
# 4879                                  Infraestrutura
# 4959                                    Provias 2010
# 4965                               Caminho da Escola
#
#                           tipo_credor  \
# 2     Instituição Financeira Nacional
# 73    Instituição Financeira Nacional
# 109   Instituição Financeira Nacional
# 111   Instituição Financeira Nacional
# 184   Instituição Financeira Nacional
# ...                               ...
# 4697  Instituição Financeira Nacional
# 4871  Instituição Financeira Nacional
# 4879  Instituição Financeira Nacional
# 4959  Instituição Financeira Nacional
# 4965  Instituição Financeira Nacional
#
#                                             credor moeda        valor  \
# 2                          Caixa Econômica Federal  Real    495000.00
# 73    Banco de Desenvolvimento de Minas Gerais S/A  Real   5000000.00
# 109   Banco de Desenvolvimento de Minas Gerais S/A  Real    194300.00
# 111   Banco de Desenvolvimento de Minas Gerais S/A  Real   1151074.30
# 184                        Caixa Econômica Federal  Real  17540000.00
# ...                                            ...   ...          ...
# 4697                           Banco do Brasil S/A  Real    321000.00
# 4871  Banco de Desenvolvimento de Minas Gerais S/A  Real    187933.65
# 4879  Banco de Desenvolvimento de Minas Gerais S/A  Real   5000000.00
# 4959  Banco de Desenvolvimento de Minas Gerais S/A  Real    627000.00
# 4965                           Banco do Brasil S/A  Real    278000.00
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 2                    0                      0  06/02/2013
# 73                   0                      0  09/11/2012
# 109                  0                      0  24/01/2013
# 111                  0                      0  29/05/2012
# 184                  0                      0  28/12/2020
# ...                ...                    ...         ...
# 4697                 0                      0  21/01/2013
# 4871                 0                      0  29/11/2012
# 4879                 0                      0  23/05/2012
# 4959                 0                      0  28/01/2013
# 4965                 0                      0  16/10/2014
#
# [65 rows x 18 columns]

# %%
# 3) Seu código aqui
uf = 'BA'
tipo_interessado = 'Município'

df_filtrado = uf_tipo(uf, tipo_interessado)

df_arquivado = df_filtrado
df_arquivado.interessado.value_counts()
# Out:
# interessado
# Camaçari                  6
# Vitória da Conquista      5
# Itatim                    5
# Santo Antônio de Jesus    5
# Baianópolis               4
#                          ..
# Mucuri                    1
# Lapão                     1
# Taperoá                   1
# Macarani                  1
# Canudos                   1
# Name: count, Length: 158, dtype: int64

# %%
# 4) Seu código aqui
uf = 'BA'
tipo_interessado = 'Estado'

df_filtrado = uf_tipo(uf, tipo_interessado)
df_filtrado.to_csv('Dados_de_solicitações_Bahia.csv')
