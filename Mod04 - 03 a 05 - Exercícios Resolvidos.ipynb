# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui

pc_mat = df_mat / 24
pc_por = df_por / 18
pc_geo = df_geo /  8
pc_ing = df_ing /  8
pc_his = df_his /  8
pc_fis = df_fis /  8
pc_qui = df_qui /  8

# %%
# 2) Seu código aqui
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
total/90
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui
total_gt_45 = total[total['Qt_acertos'] > 45]
total_gt_45.count()
# Out:
# Qt_acertos    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# 1)
# seu código aqui
df_eliminados = total[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)]

df_eliminados
# Out:
#     Qt_acertos
# 3           32
# 6           29
# 10          31
# 12          42
# 14          31
# 20          53
# 25          27
# 26          40
# 27          50
# 33          39
# 35          48
# 49          19
# 56          39
# 65          24
# 66          31
# 72          50
# 73          37
# 74          39
# 84          26
# 89          63
# 92          40
# 94          25
# 98          40

# %%
# 2)
num_eliminados = df_eliminados.shape[0]
num_eliminados
# Out:
# 23

# %%
# 3)
media_his_geo = pd.concat([df_his.loc[df_eliminados.index], df_geo.loc[df_eliminados.index]], axis=1).mean()
media_his_geo
# Out:
# Qt_acertos    3.434783
# Qt_acertos    3.217391
# dtype: float64

# %%
# 4)
df_aprovados = total[
    (total['Qt_acertos'] > 45) &
    (~total.index.isin(df_eliminados.index))]
df_aprovados
# Out:
#     Qt_acertos
# 1           48
# 2           50
# 5           50
# 7           49
# 8           58
# 17          52
# 18          50
# 24          50
# 31          54
# 36          56
# 37          52
# 39          49
# 40          47
# 42          48
# 45          48
# 48          55
# 60          48
# 62          46
# 67          46
# 70          62
# 71          53
# 77          53
# 78          66
# 81          55
# 88          50
# 93          56

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-4f036f2c-d523-41ab-8ed7-b18617784541.c000.csv'

# %%
# 1) Sua solução aqui
df = pd.read_csv(arquivo, sep=';')
df['vacina_lote'].nunique()
# Out:
# 382

# %%
df.head()
# Out:
#                                  document_id  \
# 0  f0983567-ff31-4559-9e7a-9515bb63548d-i0b0
# 1  dd097975-d896-4adc-97a1-5de3f51792a4-i0b0
# 2  c813ea08-83fd-4bf3-9448-7c9c5cc4651c-i0b0
# 3  dd180d26-5bee-44d5-a4d5-ea314976d7f1-i0b0
# 4  e4b0f671-449e-40d6-8466-36da3f5df8bb-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  0170feb383aed6e4aacf307a32fcc49b4e31149cb0fa4b...              35
# 1  5310f2da2074b4d20620f811323a6f7c4fc8853fc5a41f...              22
# 2  f715d7cad5fbb8291d01b367cda92794ffcc2d4853d444...              12
# 3  d0a264fe07e8b95225c45d61cd6f1c020c1dec5d5f1125...              68
# 4  34a27efe200d3f0ca5a0a8a6d03ef5ba80238f9d1f06c9...              16
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1986-03-08                          M                        4
# 1              1998-08-09                          F                       99
# 2              2009-01-18                          M                        3
# 3              1953-03-01                          F                        3
# 4              2005-06-18                          M                        4
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0                AMARELA                           120040.0
# 1         SEM INFORMACAO                           120013.0
# 2                  PARDA                           120043.0
# 3                  PARDA                           120040.0
# 4                AMARELA                           120040.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                    RIO BRANCO  ...
# 1                      10.0                        BUJARI  ...
# 2                      10.0           SANTA ROSA DO PURUS  ...
# 3                      10.0                    RIO BRANCO  ...
# 4                      10.0                    RIO BRANCO  ...
#
#   vacina_categoria_codigo vacina_categoria_nome  vacina_lote  \
# 0                     2.0          Faixa Etária       FA9090
# 1                     2.0          Faixa Etária       FA9096
# 2                     2.0          Faixa Etária       FF8848
# 3                     2.0          Faixa Etária       FH4750
# 4                     2.0          Faixa Etária       FF8840
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                 PFIZER   Organization/00394544000851           2021-07-03
# 1                 PFIZER   Organization/00394544000851           2021-07-23
# 2                 PFIZER   Organization/00394544000851           2021-10-18
# 3                 PFIZER            Organization/28290           2021-11-25
# 4                 PFIZER   Organization/00394544000851           2021-09-29
#
#   vacina_descricao_dose  vacina_codigo                  vacina_nome  \
# 0               1ª Dose             87  COVID-19 PFIZER - COMIRNATY
# 1               1ª Dose             87  COVID-19 PFIZER - COMIRNATY
# 2               2ª Dose             87  COVID-19 PFIZER - COMIRNATY
# 3               Reforço             87  COVID-19 PFIZER - COMIRNATY
# 4               2ª Dose             87  COVID-19 PFIZER - COMIRNATY
#
#   sistema_origem
# 0       Novo PNI
# 1       Novo PNI
# 2       Novo PNI
# 3       Novo PNI
# 4       Novo PNI
#
# [5 rows x 32 columns]

# %%
df.shape[0]
# Out:
# 390911

# %%
# 2) 
df['paciente_id'].nunique()
# Out:
# 318850

# %%
# 3) 
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df['paciente_id'].loc[df['vacina_descricao_dose'] == primeira_dose].nunique()
# Out:
# 143753

# %%
# 3) solução alternativa
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df_primeira_dose = df[df['vacina_descricao_dose'] == primeira_dose]
df_primeira_dose['paciente_id'].nunique()
# Out:
# 143753

# %%
# 4) 
df_menor = df[df["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 69726

# %%
# 5)
df['estabelecimento_razaoSocial'].nunique()
# Out:
# 64

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vacinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 
df_menor = df[df["paciente_idade"]<18].copy()

# %%
# 2) 
df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
#       dtype='object')

# %%
# 3)
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Faixa Etária                                      49015
# Povos Indígenas                                    4934
# Outros                                             3755
# Povos e Comunidades Tradicionais                    875
# Trabalhadores de Saúde                              264
# Comorbidades                                         58
# População Privada de Liberdade                       53
# Gestantes                                            47
# Trabalhadores da Educação                            14
# Trabalhadores de Transporte                          13
# Pessoas com Deficiência                              11
# Pessoas Institucionalizadas                           3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Puérperas                                             1
# Name: count, dtype: int64

# %%
# 4)
lista_variaveis = ['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']

# %%
# 5)
df_menor_lista = df_menor.loc[:,lista_variaveis]
df_menor_lista
# Out:
#         estabelecimento_valor  \
# 2                     2001772
# 4                     6917291
# 8                     2000555
# 10                    6430201
# 18                    7232489
# ...                       ...
# 390888                3015548
# 390897                2002914
# 390902                7014147
# 390904                6917291
# 390910                2001772
#
#                             estabelecimento_razaoSocial  \
# 2           PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
# 4                    PREFEITURA MUNICIPAL DE RIO BRANCO
# 8               PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 10      DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA
# 18                        PREFEITURA MUNICIPAL DE SAUDE
# ...                                                 ...
# 390888               PREFEITURA MUNICIPAL DE RIO BRANCO
# 390897          PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 390902                    PREFEITURA MUNICIPAL DE FEIJO
# 390904               PREFEITURA MUNICIPAL DE RIO BRANCO
# 390910      PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
#
#                                  estalecimento_noFantasia  \
# 2                   CENTRO DE SAUDE PAULO ALCIONE MARQUES
# 4       DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 8                     UNIDADE BASICA DE SAUDE PENTECOSTES
# 10                                     POLO BASE INDIGENA
# 18      UNIDADE DE SAUDE DA FAMILIA FRANCISCO SOUZA DO...
# ...                                                   ...
# 390888                              USF PLATILDE OLIVEIRA
# 390897              UNIDADE SAUDE DA FAMILIA 25 DE AGOSTO
# 390902                   U S F ANTONIO DOMINGOS RODRIGUES
# 390904  DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 390910              CENTRO DE SAUDE PAULO ALCIONE MARQUES
#
#         estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 2                                 120043            SANTA ROSA DO PURUS
# 4                                 120040                     RIO BRANCO
# 8                                 120020                CRUZEIRO DO SUL
# 10                                120032                         JORDAO
# 18                                120020                CRUZEIRO DO SUL
# ...                                  ...                            ...
# 390888                            120040                     RIO BRANCO
# 390897                            120020                CRUZEIRO DO SUL
# 390902                            120030                          FEIJO
# 390904                            120040                     RIO BRANCO
# 390910                            120043            SANTA ROSA DO PURUS
#
#        estabelecimento_uf
# 2                      AC
# 4                      AC
# 8                      AC
# 10                     AC
# 18                     AC
# ...                   ...
# 390888                 AC
# 390897                 AC
# 390902                 AC
# 390904                 AC
# 390910                 AC
#
# [79220 rows x 6 columns]

# %%
# 6)
df_menor_lista = df_menor_lista.drop_duplicates()
df_menor_lista
# Out:
#         estabelecimento_valor  \
# 2                     2001772
# 4                     6917291
# 8                     2000555
# 10                    6430201
# 18                    7232489
# ...                       ...
# 200308                2001357
# 240602                4646770
# 337877                6411312
# 358667                2000814
# 370287                2832798
#
#                             estabelecimento_razaoSocial  \
# 2           PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
# 4                    PREFEITURA MUNICIPAL DE RIO BRANCO
# 8               PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 10      DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA
# 18                        PREFEITURA MUNICIPAL DE SAUDE
# ...                                                 ...
# 200308       SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 240602                                USF SAO FRANCISCO
# 337877        PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO
# 358667            SECRETARIA DE ESTADO DE SAUDE DO ACRE
# 370287           PREFEITURA MUNICIPAL DE EPITACIOLANDIA
#
#                                  estalecimento_noFantasia  \
# 2                   CENTRO DE SAUDE PAULO ALCIONE MARQUES
# 4       DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 8                     UNIDADE BASICA DE SAUDE PENTECOSTES
# 10                                     POLO BASE INDIGENA
# 18      UNIDADE DE SAUDE DA FAMILIA FRANCISCO SOUZA DO...
# ...                                                   ...
# 200308                        ESF PEDRO OLIVEIRA DE SOUZA
# 240602                                  USF SAO FRANCISCO
# 337877                         U S F LUCIO ALVES DA SILVA
# 358667                     USF FRANCISCO EDUARDO DE PAIVA
# 370287        UNIDADE DE SAUDE ALBERTO FLORENCIO DA SILVA
#
#         estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 2                                 120043            SANTA ROSA DO PURUS
# 4                                 120040                     RIO BRANCO
# 8                                 120020                CRUZEIRO DO SUL
# 10                                120032                         JORDAO
# 18                                120020                CRUZEIRO DO SUL
# ...                                  ...                            ...
# 200308                            120010                      BRASILEIA
# 240602                            120040                     RIO BRANCO
# 337877                            120038              PLACIDO DE CASTRO
# 358667                            120040                     RIO BRANCO
# 370287                            120025                 EPITACIOLANDIA
#
#        estabelecimento_uf
# 2                      AC
# 4                      AC
# 8                      AC
# 10                     AC
# 18                     AC
# ...                   ...
# 200308                 AC
# 240602                 AC
# 337877                 AC
# 358667                 AC
# 370287                 AC
#
# [213 rows x 6 columns]
